# %% [markdown]
# ## Exploratory Analysis on Cars data

# %%
# %%pyspark
# data_path = spark.read.load('abfss://azureudemeycoursewsfs@azureudemeycoursewsadls.dfs.core.windows.net/cars_dataset_details.parquet', format='parquet')
# data_path.show(100)
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+--------------------+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|               owner|
# +--------------------+----+-------------+---------+------+-----------+------------+--------------------+
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual|         First Owner|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual|         First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual|         First Owner|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual|         First Owner|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|        Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual|         First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual|         First Owner|
# |Tata Indigo Grand...|2014|       240000|    60000|Petrol| Individual|      Manual|        Second Owner|
# |Hyundai Creta 1.6...|2015|       850000|    25000|Petrol| Individual|      Manual|         First Owner|
# |Maruti Celerio Gr...|2017|       365000|    78000|   CNG| Individual|      Manual|         First Owner|
# |Chevrolet Sail 1....|2015|       260000|    35000|Petrol| Individual|      Manual|         First Owner|
# |Tata Indigo Grand...|2014|       250000|   100000|Petrol| Individual|      Manual|         First Owner|
# |Toyota Corolla Al...|2018|      1650000|    25000|Petrol|     Dealer|   Automatic|         First Owner|
# |       Maruti 800 AC|2007|        60000|    70000|Petrol| Individual|      Manual|         First Owner|
# |Maruti Wagon R LX...|2007|       135000|    50000|Petrol| Individual|      Manual|         First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|   100000|Diesel| Individual|      Manual|         First Owner|
# |Datsun RediGO T O...|2017|       250000|    46000|Petrol| Individual|      Manual|         First Owner|
# |Honda Amaze VX i-...|2014|       450000|   141000|Diesel| Individual|      Manual|        Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|   125000|Petrol| Individual|      Manual|         First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|    25000|Petrol| Individual|      Manual|         First Owner|
# |Tata Indigo Grand...|2014|       240000|    60000|Petrol| Individual|      Manual|        Second Owner|
# |Hyundai Creta 1.6...|2015|       850000|    25000|Petrol| Individual|      Manual|         First Owner|
# |Maruti Celerio Gr...|2017|       365000|    78000|   CNG| Individual|      Manual|         First Owner|
# |Chevrolet Sail 1....|2015|       260000|    35000|Petrol| Individual|      Manual|         First Owner|
# |Tata Indigo Grand...|2014|       250000|   100000|Petrol| Individual|      Manual|         First Owner|
# |Toyota Corolla Al...|2018|      1650000|    25000|Petrol|     Dealer|   Automatic|         First Owner|
# |Maruti Ciaz VXi Plus|2015|       585000|    24000|Petrol|     Dealer|      Manual|         First Owner|
# |Hyundai Venue SX ...|2019|      1195000|     5000|Diesel|     Dealer|      Manual|         First Owner|
# |Chevrolet Enjoy T...|2013|       390000|    33000|Diesel| Individual|      Manual|        Second Owner|
# |Jaguar XF 2.2 Lit...|2014|      1964999|    28000|Diesel|     Dealer|   Automatic|         First Owner|
# |Mercedes-Benz New...|2013|      1425000|    59000|Diesel|     Dealer|   Automatic|         First Owner|
# |Maruti Vitara Bre...|2018|       975000|     4500|Diesel|     Dealer|   Automatic|         First Owner|
# |     Audi Q5 2.0 TDI|2011|      1190000|   175900|Diesel|     Dealer|   Automatic|         First Owner|
# |     Honda City V MT|2018|       930000|    14500|Petrol|     Dealer|      Manual|         First Owner|
# |Tata Tigor 1.2 Re...|2018|       525000|    15000|Petrol| Individual|      Manual|         First Owner|
# |Audi A6 2.0 TDI  ...|2013|      1735000|    50000|Diesel|     Dealer|   Automatic|         First Owner|
# |Mercedes-Benz New...|2012|      1375000|    33800|Diesel|     Dealer|   Automatic|        Second Owner|
# |Skoda Superb Ambi...|2011|       450000|   130400|Diesel|     Dealer|   Automatic|        Second Owner|
# |Toyota Corolla Al...|2016|       900000|    50000|Petrol| Individual|   Automatic|         First Owner|
# |Toyota Innova 2.5...|2015|      1300000|    80000|Diesel| Individual|      Manual|         First Owner|
# |Jeep Compass 1.4 ...|2019|      1400000|    10000|Petrol| Individual|      Manual|         First Owner|
# |Mercedes-Benz E-C...|2010|       850000|   119000|Petrol|     Dealer|   Automatic|         First Owner|
# |Hyundai i10 Magna...|2014|       229999|    60000|Petrol| Individual|      Manual|Fourth & Above Owner|
# |BMW 3 Series 320d...|2013|      1550000|    75800|Diesel|     Dealer|   Automatic|        Second Owner|
# |Audi Q7 35 TDI Qu...|2009|      1250000|    78000|Diesel|     Dealer|   Automatic|         Third Owner|
# |Hyundai Elantra C...|2012|       625000|    40000|Diesel| Individual|      Manual|         First Owner|
# |Mahindra Scorpio ...|2014|      1050000|    50000|Diesel| Individual|      Manual|         First Owner|
# | Honda City i DTEC V|2014|       560000|    74000|Diesel| Individual|      Manual|        Second Owner|
# |Maruti Wagon R VX...|2014|       290000|    64000|Petrol| Individual|      Manual|        Second Owner|
# |Maruti Wagon R VX...|2012|       275000|    60000|Petrol| Individual|      Manual|        Second Owner|
# | Mahindra Scorpio LX|2009|       411000|   120000|Diesel| Individual|      Manual|        Second Owner|
# |Hyundai Santro Xi...|2009|       150000|    79000|Petrol| Individual|      Manual|         Third Owner|
# |Hyundai Grand i10...|2019|       500000|    15000|Petrol| Individual|      Manual|         First Owner|
# |     Maruti Alto LXi|2006|       100000|    80000|Petrol| Individual|      Manual|         First Owner|
# |Maruti Swift Dzir...|2017|       725000|    18500|Diesel|     Dealer|      Manual|         First Owner|
# |Maruti Eeco 5 Sea...|2018|       401000|    10200|Petrol|     Dealer|      Manual|         First Owner|
# |Hyundai i20 Sport...|2018|       750000|    29000|Diesel|     Dealer|      Manual|         First Owner|
# |Maruti Omni Marut...|2018|       310000|    28000|Petrol|     Dealer|      Manual|         First Owner|
# |Maruti Swift ZDi ...|2016|       665000|    46000|Diesel|     Dealer|      Manual|         First Owner|
# |Hyundai i20 2015-...|2014|       465000|    70000|Diesel|     Dealer|      Manual|         First Owner|
# |     Maruti Alto LXi|2012|       160000|    60000|Petrol| Individual|      Manual|        Second Owner|
# |Mahindra Jeep CL ...|1996|       250000|    35000|Diesel| Individual|      Manual|        Second Owner|
# |Honda City i DTEC VX|2014|       675000|    90000|Diesel|     Dealer|      Manual|         First Owner|
# |Maruti Wagon R VX...|2013|       300000|    80000|Petrol|     Dealer|      Manual|         First Owner|
# |     Tata Indica DLS|2005|        70000|    80000|Diesel| Individual|      Manual|         First Owner|
# |Hyundai EON Magna...|2014|       240000|    73300|Petrol|     Dealer|      Manual|        Second Owner|
# |     Toyota Etios GD|2014|       525000|    92000|Diesel|     Dealer|      Manual|         First Owner|
# |     Maruti Alto LXi|2009|       151000|    66764|Petrol|     Dealer|      Manual|        Second Owner|
# |     Maruti Alto LXi|2009|       140000|   100000|Petrol| Individual|      Manual|         First Owner|
# |Chevrolet Tavera ...|2010|       280000|   350000|Diesel| Individual|      Manual|        Second Owner|
# |Toyota Corolla Al...|2011|       350000|   230000|Diesel| Individual|      Manual|         First Owner|
# |Mahindra Scorpio ...|2017|       570000|    60000|Diesel| Individual|      Manual|         First Owner|
# |Hyundai EON Magna...|2018|       300000|    31000|Petrol| Individual|      Manual|         First Owner|
# |Tata Indigo Class...|2007|       100000|    39000|Diesel| Individual|      Manual|         First Owner|
# |Toyota Innova 2.5...|2009|       500000|   120000|Diesel| Individual|      Manual|         Third Owner|
# |Tata Indica Vista...|2014|       125000|   166000|Diesel| Individual|      Manual|Fourth & Above Owner|
# |Maruti Swift 1.3 VXi|2006|       130000|   110000|Petrol| Individual|      Manual|         Third Owner|
# |Ford EcoSport 1.5...|2017|       925000|    35000|Diesel| Individual|      Manual|         First Owner|
# |Maruti Ciaz 1.3 D...|2018|       750000|    60000|Diesel| Individual|      Manual|         First Owner|
# |Honda Civic 1.8 V AT|2007|       200000|    54000|Petrol| Individual|   Automatic|        Second Owner|
# |Hyundai i10 Sport...|2010|       248000|    63000|Petrol| Individual|      Manual|        Second Owner|
# |Skoda Rapid 1.5 T...|2014|       450000|   120000|Diesel| Individual|      Manual|        Second Owner|
# |    Hyundai Getz GLS|2005|        80000|   120000|Petrol| Individual|      Manual|         Third Owner|
# |   Nissan Terrano XL|2014|       650000|    76000|Petrol| Individual|      Manual|        Second Owner|
# |Hyundai Grand i10...|2015|       450000|    80000|Diesel| Individual|      Manual|         First Owner|
# |Hyundai Elite i20...|2019|       650000|    25000|Diesel| Individual|      Manual|         First Owner|
# |Honda Amaze S i-VTEC|2016|       495000|    11958|Petrol|     Dealer|      Manual|         First Owner|
# |     Honda Brio S MT|2015|       371000|    20000|Petrol|     Dealer|      Manual|         First Owner|
# |Hyundai Creta 1.6...|2017|      1025000|     9000|Petrol|     Dealer|      Manual|         First Owner|
# |Mercedes-Benz S-C...|2017|      8150000|     6500|Diesel|     Dealer|   Automatic|         First Owner|
# |Mahindra XUV500 W...|2015|       750000|    70000|Diesel| Individual|      Manual|         First Owner|
# |Renault Duster 85...|2013|       600000|   120000|Diesel| Individual|      Manual|         First Owner|
# |Hyundai Santro Xi...|2007|        80000|    58000|Petrol|     Dealer|      Manual|        Second Owner|
# |Mahindra Bolero 2...|2013|       325000|    62200|Diesel|     Dealer|      Manual|         First Owner|
# |Audi A6 2.0 TDI P...|2014|      1470000|    34000|Diesel|     Dealer|   Automatic|        Second Owner|
# |Fiat Avventura MU...|2015|       350000|    53000|Diesel| Individual|      Manual|        Second Owner|
# |     Audi A8 4.2 TDI|2013|      2800000|    49000|Diesel|     Dealer|   Automatic|         First Owner|
# | Datsun RediGO 1.0 S|2017|       210000|    15000|Petrol|     Dealer|      Manual|        Second Owner|
# |Volkswagen Jetta ...|2013|       450000|    50000|Petrol| Individual|      Manual|         First Owner|
# |Audi A4 2.0 TDI 1...|2013|      1150000|    53000|Diesel|     Dealer|   Automatic|         First Owner|
# +--------------------+----+-------------+---------+------+-----------+------------+--------------------+
# only showing top 100 rows

# %%
#converting spark dataframe to pandas
df = data_path.select("*").toPandas()
df
# Out:
# name  year  ... transmission         owner
# 0                           Maruti 800 AC  2007  ...       Manual   First Owner
# 1                Maruti Wagon R LXI Minor  2007  ...       Manual   First Owner
# 2                    Hyundai Verna 1.6 SX  2012  ...       Manual   First Owner
# 3                  Datsun RediGO T Option  2017  ...       Manual   First Owner
# 4                   Honda Amaze VX i-DTEC  2014  ...       Manual  Second Owner
# ...                                   ...   ...  ...          ...           ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014  ...       Manual  Second Owner
# 4336           Hyundai i20 Magna 1.4 CRDi  2014  ...       Manual  Second Owner
# 4337                  Maruti 800 AC BSIII  2009  ...       Manual  Second Owner
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016  ...       Manual   First Owner
# 4339                     Renault KWID RXT  2016  ...       Manual   First Owner
#
# [4340 rows x 8 columns]
# /home/trusted-service-user/cluster-env/env/lib/python3.6/site-packages/pyarrow/util.py:39: FutureWarning: pyarrow.open_stream is deprecated as of 0.17.0, please use pyarrow.ipc.open_stream instead
#   warnings.warn(msg, FutureWarning)

# %%
# Checking missing and null values
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
import datetime
import pandas as pd
from dateutil.relativedelta import relativedelta
df['Years2Date'] = pd.to_datetime(df['year'].map(str), format='%Y-%m-%d %H:%M:%S')
df['CurrentYear'] = pd.to_datetime(datetime.datetime.now(), format='%Y-%m-%d %H:%M:%S')

# %%
df['TotalOwnershipinDays'] =pd.to_timedelta(df['CurrentYear']-df['Years2Date'], unit='D')
df['TotalOwnershipinDays']= df['TotalOwnershipinDays'].astype(str)
df[['Days','Time','Etc']] = df.TotalOwnershipinDays.str.split(" ",expand=True,)
df['Age']=df['Days'].map(int)/365
df
# Out:
# name  year  ...              Etc        Age
# 0                           Maruti 800 AC  2007  ...  21:16:22.744627  13.616438
# 1                Maruti Wagon R LXI Minor  2007  ...  21:16:22.744627  13.616438
# 2                    Hyundai Verna 1.6 SX  2012  ...  21:16:22.744627   8.613699
# 3                  Datsun RediGO T Option  2017  ...  21:16:22.744627   3.608219
# 4                   Honda Amaze VX i-DTEC  2014  ...  21:16:22.744627   6.610959
# ...                                   ...   ...  ...              ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014  ...  21:16:22.744627   6.610959
# 4336           Hyundai i20 Magna 1.4 CRDi  2014  ...  21:16:22.744627   6.610959
# 4337                  Maruti 800 AC BSIII  2009  ...  21:16:22.744627  11.613699
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016  ...  21:16:22.744627   4.610959
# 4339                     Renault KWID RXT  2016  ...  21:16:22.744627   4.610959
#
# [4340 rows x 15 columns]

# %%
# %%pyspark
# spark.conf.set("spark.sql.execution.arrow.enabled", "true")
# sdf = spark.createDataFrame(df)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:714: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.enabled' is set to true; however, failed by the reason below:
#   'JavaPackage' object is not callable
# Attempting non-optimization as 'spark.sql.execution.arrow.fallback.enabled' is set to true.

# %%
# %%pyspark
# sdf.registerTempTable("car_prices_details_with_age_in_years")

# %%
# %%sql
# SELECT * FROM car_prices_details_with_age_in_years
